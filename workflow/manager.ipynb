# %% [markdown]
# # Spatial Selection

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("..")   

# Importing fields and counties
counties = gpd.read_file("/workspace/workflow/counties.geojson")
counties = counties[['name','geometry']]
counties.columns=['countyname','geometry']

fields=gpd.read_file("/workspace/workflow/_2GridSampling/field_final_sample.geojson")
fields=fields[['id_cell','id_within_cell','geometry']]

# Mapping Region
region3_map = {
    # NW
    "Jasper County": "NC", "Lake County": "NC", "Laporte County": "NC", "Newton County": "NC", "Porter County": "NC", "Pulaski County": "NC", "Starke County": "NC", "White County": "NC",
    # NC
    "Kosciusko County":"NC","Wabash County":"NC","St Joseph County":"NC","Cass County": "NC", "Fulton County": "NC", "Howard County": "C", "Miami County": "NC", "Tippecanoe County": "NC", "Tipton County": "C", "Carroll County": "NC", "Clinton County": "C","Marshall County":"NC","Elkhart County":"NC",
    # NE
    "Adams County": "NE", "Allen County": "NE", "Dekalb County": "NE", "Huntington County": "NE", "Lagrange County": "NE", "Noble County": "NE", "Steuben County": "NE", "Wells County": "NE", "Whitley County": "NE",
    # WC
    "Benton County": "NC", "Fountain County": "NC", "Montgomery County": "NC", "Parke County": "NC", "Putnam County": "NC", "Vermillion County": "NC", "Warren County": "NC","Vigo County": "NC","Clay County": "NC",
    # C
    "Boone County": "C", "Hamilton County": "C", "Hancock County": "C", "Hendricks County": "C", "Johnson County": "C", "Madison County": "C", "Marion County": "C", "Morgan County": "C", "Shelby County": "C",
    # EC
    "Blackford County": "NE","Union County": "NE","Fayette County": "NE", "Delaware County": "NE", "Grant County": "C", "Henry County": "NE", "Jay County": "NE", "Randolph County":"NE","Rush County":"C","Wayne County":"NE",
    
    "Daviess County": "NC", "Sullivan County": "NC","Gibson County": "NC", "Knox County": "NC", "Perry County": "NC", "Pike County": "NC", "Posey County": "NC", "Spencer County": "NC", "Vanderburgh County": "NC", "Warrick County": "NC",
    # SC
    "Brown County": "NC", "Crawford County": "NC", "Dubois County": "NC", "Greene County": "NC", "Lawrence County": "NC", "Martin County": "NC", "Monroe County": "NC", "Orange County": "NC", "Owen County": "NC", "Washington County": "NC",
    # SE
    "Bartholomew County": "C", "Clark County": "NC", "Decatur County": "C", "Dearborn County": "NC", "Floyd County": "NC", "Franklin County": "NC", "Harrison County": "NC", "Jackson County": "NC", "Jefferson County": "NC", "Jennings County": "NC", "Ohio County": "NC", "Ripley County": "NC", "Scott County": "NC", "Switzerland County": "NC"
}

# region9_map = {
#     # NW
#     "Jasper County": "NW", "Lake County": "NW", "Laporte County": "NW", "Newton County": "NW", "Porter County": "NW", "Pulaski County": "NW", "Starke County": "NW", "White County": "NW",
#     # NC
#     "Kosciusko County":"NC","Wabash County":"NC","St Joseph County":"NC","Cass County": "NC", "Fulton County": "NC", "Howard County": "C", "Miami County": "NC", "Tippecanoe County": "WC", "Tipton County": "C", "Carroll County": "NC", "Clinton County": "C","Marshall County":"NC","Elkhart County":"NC",
#     # NE
#     "Adams County": "NE", "Allen County": "NE", "Dekalb County": "NE", "Huntington County": "NE", "Lagrange County": "NE", "Noble County": "NE", "Steuben County": "NE", "Wells County": "NE", "Whitley County": "NE",
#     # WC
#     "Benton County": "NW", "Fountain County": "WC", "Montgomery County": "WC", "Parke County": "WC", "Putnam County": "WC", "Vermillion County": "WC", "Warren County": "WC","Vigo County": "WC","Clay County": "WC",
#     # C
#     "Boone County": "C", "Hamilton County": "C", "Hancock County": "C", "Hendricks County": "C", "Johnson County": "C", "Madison County": "C", "Marion County": "C", "Morgan County": "C", "Shelby County": "C",
#     # EC
#     "Blackford County": "EC","Union County": "EC","Fayette County": "EC", "Delaware County": "EC", "Grant County": "C", "Henry County": "EC", "Jay County": "EC", "Randolph County": "EC", "Rush County": "C", "Wayne County": "EC",
#     # SW
#     "Daviess County": "SW", "Sullivan County": "SW","Gibson County": "SW", "Knox County": "SW", "Perry County": "SC", "Pike County": "SW", "Posey County": "SW", "Spencer County": "SW", "Vanderburgh County": "SW", "Warrick County": "SW",
#     # SC
#     "Brown County": "SC", "Crawford County": "SC", "Dubois County": "SW", "Greene County": "SW", "Lawrence County": "SC", "Martin County": "SW", "Monroe County": "SC", "Orange County": "SC", "Owen County": "WC", "Washington County": "SC",
#     # SE
#     "Bartholomew County": "C", "Clark County": "SE", "Decatur County": "C", "Dearborn County": "SE", "Floyd County": "SC", "Franklin County": "SE", "Harrison County": "SC", "Jackson County": "SC", "Jefferson County": "SE", "Jennings County": "SE", "Ohio County": "SE", "Ripley County": "SE", "Scott County": "SE", "Switzerland County": "SE"
# }

counties["region"] = counties["countyname"].map(region3_map).fillna("Other/SandNI")
counties=counties[["region","countyname","geometry"]]

fields = fields.to_crs(counties.crs)

region_fields = gpd.sjoin(fields, counties, how='inner', predicate='intersects')

region_fields_sample = (
    region_fields.groupby('region', group_keys=False) 
       .apply(lambda x: x.sample(n=20, random_state=42)) 
)
region_fields_sample.reset_index(drop=True, inplace=True)

region_fields_sample.to_file("/workspace/workflow/_3AgroDataExtraction/calibration_sample.geojson", driver="GeoJSON")
# Out:
# /tmp/ipykernel_961/641708726.py:67: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(n=20, random_state=42))

# %% [markdown]
# # Features Extraction

# %%
# !python -m _3AgroDataExtraction
# Out:
# 1980-01-01T00:00:00
# 2024-12-31T00:00:00
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  29.0  15.0  56.0  1.50  ...   8.2   260.0      605               2
# 1  20.0  29.0  51.0  1.60  ...  15.6   160.0      605               2
# 2  39.0  31.0  30.0  1.73  ...  16.5   310.0      605               2
# 3  41.0  25.0  34.0  1.73  ...  11.2   180.0      605               2
# 4  44.0  17.0  39.0  1.80  ...   7.6  1090.0      605               2
#
# [5 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_605_2.met
# Weather and Soil Variables extracted for field 605-2
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  15.0  35.0  50.0  1.66  ...  30.0  280.0     1021               2
# 1  16.0  42.0  42.0  1.80  ...  24.0  580.0     1021               2
# 2  16.0  42.0  42.0  1.80  ...  18.0  340.0     1021               2
# 3  21.0  35.0  44.0  1.80  ...  12.0  250.0     1021               2
# 4  23.0  33.0  44.0  1.80  ...  15.0  550.0     1021               2
#
# [5 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_1021_2.met
# Weather and Soil Variables extracted for field 1021-2
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  17.0  14.0  69.0  1.52  ...  15.0  250.0      613               3
# 1  13.0  17.0  70.0  1.52  ...  15.0   80.0      613               3
# 2  10.0  29.0  61.0  1.71  ...  20.0  360.0      613               3
# 3  40.0  28.0  32.0  1.80  ...  20.0  580.0      613               3
# 4  45.0  20.0  35.0  1.80  ...  10.0  230.0      613               3
# 5  45.0  15.0  40.0  1.80  ...  10.0  500.0      613               3
#
# [6 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_613_3.met
# Weather and Soil Variables extracted for field 613-3
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  35.0  28.0  37.0  1.64  ...  23.6  250.0      828               2
# 1  35.0  32.0  33.0  1.80  ...  25.6  820.0      828               2
# 2  45.0  27.0  28.0  1.79  ...  21.9  170.0      828               2
# 3  87.0   3.0  10.0  1.71  ...   2.8  760.0      828               2
#
# [4 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_828_2.met
# Weather and Soil Variables extracted for field 828-2
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  29.0  15.0  56.0  1.50  ...   8.2   260.0      653               1
# 1  20.0  29.0  51.0  1.60  ...  15.6   160.0      653               1
# 2  39.0  31.0  30.0  1.73  ...  16.5   310.0      653               1
# 3  41.0  25.0  34.0  1.73  ...  11.2   180.0      653               1
# 4  44.0  17.0  39.0  1.80  ...   7.6  1090.0      653               1
#
# [5 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_653_1.met
# Weather and Soil Variables extracted for field 653-1
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  26.0  13.0  61.0  1.52  ...  10.0  250.0     1056               1
# 1  25.0  16.0  59.0  1.52  ...  10.0  130.0     1056               1
# 2  23.0  26.0  51.0  1.65  ...  14.0   80.0     1056               1
# 3  31.0  28.0  41.0  1.67  ...  14.0  480.0     1056               1
# 4  65.0  21.0  14.0  1.75  ...  11.0  300.0     1056               1
# 5  89.0   3.0   8.0  1.80  ...   2.0  760.0     1056               1
#
# [6 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_1056_1.met
# Weather and Soil Variables extracted for field 1056-1
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  29.0  15.0  56.0  1.50  ...   8.2   260.0      791               1
# 1  20.0  29.0  51.0  1.60  ...  15.6   160.0      791               1
# 2  39.0  31.0  30.0  1.73  ...  16.5   310.0      791               1
# 3  41.0  25.0  34.0  1.73  ...  11.2   180.0      791               1
# 4  44.0  17.0  39.0  1.80  ...   7.6  1090.0      791               1
#
# [5 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_791_1.met
# Weather and Soil Variables extracted for field 791-1
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT   BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  22.0  22.0  56.0  1.5  ...  18.0   250.0      840               2
# 1  16.0  42.0  42.0  1.8  ...  24.0   580.0      840               2
# 2  25.0  35.0  40.0  1.8  ...  18.0   160.0      840               2
# 3  22.0  33.0  45.0  1.8  ...  18.0  1010.0      840               2
#
# [4 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_840_2.met
# Weather and Soil Variables extracted for field 840-2
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  22.0  16.0  62.0  1.41  ...  14.4  360.0      834               1
# 1  12.0  26.0  62.0  1.55  ...  21.2  150.0      834               1
# 2  12.0  30.0  58.0  1.60  ...  24.1  730.0      834               1
# 3  35.0  24.0  41.0  1.58  ...  19.7  280.0      834               1
# 4  40.0  15.0  45.0  1.51  ...  12.7  480.0      834               1
#
# [5 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_834_1.met
# Weather and Soil Variables extracted for field 834-1
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  29.0  15.0  56.0  1.50  ...   8.2   260.0      971               4
# 1  20.0  29.0  51.0  1.60  ...  15.6   160.0      971               4
# 2  39.0  31.0  30.0  1.73  ...  16.5   310.0      971               4
# 3  41.0  25.0  34.0  1.73  ...  11.2   180.0      971               4
# 4  44.0  17.0  39.0  1.80  ...   7.6  1090.0      971               4
#
# [5 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_971_4.met
# Weather and Soil Variables extracted for field 971-4
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  17.0  27.0  56.0  1.58  ...  23.1  250.0      794               2
# 1  16.0  29.0  55.0  1.60  ...  24.5  100.0      794               2
# 2  12.0  33.0  55.0  1.80  ...  26.5  560.0      794               2
# 3  30.0  26.0  44.0  1.72  ...  20.3  590.0      794               2
# 4  40.0  18.0  42.0  1.53  ...  13.0  500.0      794               2
#
# [5 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_794_2.met
# Weather and Soil Variables extracted for field 794-2
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  15.0  35.0  50.0  1.66  ...  30.0  280.0      930               4
# 1  16.0  42.0  42.0  1.80  ...  24.0  580.0      930               4
# 2  16.0  42.0  42.0  1.80  ...  18.0  340.0      930               4
# 3  21.0  35.0  44.0  1.80  ...  12.0  250.0      930               4
# 4  23.0  33.0  44.0  1.80  ...  15.0  550.0      930               4
#
# [5 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_930_4.met
# Weather and Soil Variables extracted for field 930-4
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  17.0  14.0  69.0  1.52  ...  12.5  250.0      749               3
# 1  13.0  17.0  70.0  1.53  ...  14.7   80.0      749               3
# 2  10.0  29.0  61.0  1.70  ...  22.9  360.0      749               3
# 3  40.0  28.0  32.0  1.80  ...  21.3  580.0      749               3
# 4  45.0  20.0  35.0  1.80  ...  15.7  230.0      749               3
# 5  45.0  15.0  40.0  1.80  ...  12.1  500.0      749               3
#
# [6 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_749_3.met
# Weather and Soil Variables extracted for field 749-3
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  20.0  16.0  64.0  1.52  ...   8.7   200.0      658               3
# 1  31.0  29.0  40.0  1.80  ...  15.4   590.0      658               3
# 2  38.0  22.0  40.0  1.69  ...  11.7   120.0      658               3
# 3  36.0  20.0  44.0  1.80  ...  10.1  1090.0      658               3
#
# [4 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_658_3.met
# Weather and Soil Variables extracted for field 658-3
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  20.0  19.0  61.0  1.52  ...  14.0   250.0      559               1
# 1  40.0  22.0  38.0  1.62  ...  13.0  1070.0      559               1
# 2  50.0  15.0  35.0  1.36  ...   9.0   200.0      559               1
#
# [3 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_559_1.met
# Weather and Soil Variables extracted for field 559-1
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  22.0  16.0  62.0  1.41  ...  14.4  360.0      747               4
# 1  12.0  26.0  62.0  1.55  ...  21.2  150.0      747               4
# 2  12.0  30.0  58.0  1.60  ...  24.1  730.0      747               4
# 3  35.0  24.0  41.0  1.58  ...  19.7  280.0      747               4
# 4  40.0  15.0  45.0  1.51  ...  12.7  480.0      747               4
#
# [5 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_747_4.met
# Weather and Soil Variables extracted for field 747-4
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  18.0  18.0  64.0  1.52  ...   9.8   200.0     1012               2
# 1  20.0  17.0  63.0  1.52  ...   9.2    80.0     1012               2
# 2  20.0  25.0  55.0  1.63  ...  13.3    80.0     1012               2
# 3  18.0  40.0  42.0  1.80  ...  21.2   350.0     1012               2
# 4  33.5  26.0  40.5  1.78  ...  13.1   200.0     1012               2
# 5  42.0  17.5  40.5  1.80  ...   8.2  1090.0     1012               2
#
# [6 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_1012_2.met
# Weather and Soil Variables extracted for field 1012-2
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  17.0  14.0  69.0  1.52  ...  12.5  250.0      915               4
# 1  13.0  17.0  70.0  1.53  ...  14.7   80.0      915               4
# 2  10.0  29.0  61.0  1.70  ...  22.9  360.0      915               4
# 3  40.0  28.0  32.0  1.80  ...  21.3  580.0      915               4
# 4  45.0  20.0  35.0  1.80  ...  15.7  230.0      915               4
# 5  45.0  15.0  40.0  1.80  ...  12.1  500.0      915               4
#
# [6 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_915_4.met
# Weather and Soil Variables extracted for field 915-4
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  13.0  28.0  59.0  1.66  ...  26.0  410.0      704               2
# 1  19.0  34.0  47.0  1.73  ...  26.3  400.0      704               2
# 2  34.0  25.0  41.0  1.65  ...  20.5  310.0      704               2
# 3  36.0  15.0  49.0  1.72  ...  11.9  400.0      704               2
#
# [4 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_704_2.met
# Weather and Soil Variables extracted for field 704-2
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  29.0  15.0  56.0  1.50  ...   8.2   260.0      880               1
# 1  20.0  29.0  51.0  1.60  ...  15.6   160.0      880               1
# 2  39.0  31.0  30.0  1.73  ...  16.5   310.0      880               1
# 3  41.0  25.0  34.0  1.73  ...  11.2   180.0      880               1
# 4  44.0  17.0  39.0  1.80  ...   7.6  1090.0      880               1
#
# [5 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_880_1.met
# Weather and Soil Variables extracted for field 880-1
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  17.0  14.0  69.0  1.52  ...  12.5  250.0      888               3
# 1  13.0  17.0  70.0  1.53  ...  14.7   80.0      888               3
# 2  10.0  29.0  61.0  1.70  ...  22.9  360.0      888               3
# 3  40.0  28.0  32.0  1.80  ...  21.3  580.0      888               3
# 4  45.0  20.0  35.0  1.80  ...  15.7  230.0      888               3
# 5  45.0  15.0  40.0  1.80  ...  12.1  500.0      888               3
#
# [6 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_888_3.met
# Weather and Soil Variables extracted for field 888-3
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...  CEC   THICK  id_cell  id_within_cell
# 0  81.0   5.0  14.0  1.40  ...  NaN   210.0      854               3
# 1  90.0   4.0   6.0  1.50  ...  NaN   700.0      854               3
# 2  94.0   3.0   3.0  1.58  ...  NaN  1120.0      854               3
#
# [3 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_854_3.met
# Weather and Soil Variables extracted for field 854-3
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# ...
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC  THICK  id_cell  id_within_cell
# 0  15.0  35.0  50.0  1.66  ...  30.0  280.0      983               3
# 1  16.0  42.0  42.0  1.80  ...  24.0  580.0      983               3
# 2  16.0  42.0  42.0  1.80  ...  18.0  340.0      983               3
# 3  21.0  35.0  44.0  1.80  ...  12.0  250.0      983               3
# 4  23.0  33.0  44.0  1.80  ...  15.0  550.0      983               3
#
# [5 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_983_3.met
# Weather and Soil Variables extracted for field 983-3
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  15.0  23.0  62.0  1.51  ...  19.5   200.0     1023               1
# 1  35.0  22.0  43.0  1.54  ...  18.2   610.0     1023               1
# 2  45.0  18.0  37.0  1.54  ...  14.9  1190.0     1023               1
#
# [3 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_1023_1.met
# Weather and Soil Variables extracted for field 1023-1
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT   BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  22.0  22.0  56.0  1.5  ...  18.0   250.0     1167               1
# 1  16.0  42.0  42.0  1.8  ...  24.0   580.0     1167               1
# 2  25.0  35.0  40.0  1.8  ...  18.0   160.0     1167               1
# 3  22.0  33.0  45.0  1.8  ...  18.0  1010.0     1167               1
#
# [4 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_1167_1.met
# Weather and Soil Variables extracted for field 1167-1
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...  CEC  THICK  id_cell  id_within_cell
# 0  79.0   4.0  17.0  1.63  ...  9.0  250.0     1122               2
# 1  85.0   6.0   9.0  1.63  ...  9.0  210.0     1122               2
# 2  70.0  14.0  16.0  1.78  ...  8.5  450.0     1122               2
# 3  90.0   3.0   7.0  1.80  ...  3.0  610.0     1122               2
#
# [4 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_1122_2.met
# Weather and Soil Variables extracted for field 1122-2
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  22.0  26.0  52.0  1.58  ...  18.0   200.0     1017               2
# 1  22.0  42.0  36.0  1.80  ...  24.0   460.0     1017               2
# 2  24.0  36.0  40.0  1.80  ...  18.0   100.0     1017               2
# 3  25.0  36.0  39.0  1.80  ...  18.0  1240.0     1017               2
#
# [4 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_1017_2.met
# Weather and Soil Variables extracted for field 1017-2
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT   BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  32.0  25.0  43.0  1.6  ...  15.0   200.0     1255               3
# 1  21.0  42.0  37.0  1.8  ...  24.0   510.0     1255               3
# 2  30.0  35.0  35.0  1.8  ...  13.7   180.0     1255               3
# 3  22.0  33.0  45.0  1.8  ...  11.2  1110.0     1255               3
#
# [4 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_1255_3.met
# Weather and Soil Variables extracted for field 1255-3
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  18.0  18.0  64.0  1.52  ...   9.8   200.0     1105               1
# 1  20.0  17.0  63.0  1.52  ...   9.2    80.0     1105               1
# 2  20.0  25.0  55.0  1.63  ...  13.3    80.0     1105               1
# 3  18.0  40.0  42.0  1.80  ...  21.2   350.0     1105               1
# 4  33.5  26.0  40.5  1.78  ...  13.1   200.0     1105               1
# 5  42.0  17.5  40.5  1.80  ...   8.2  1090.0     1105               1
#
# [6 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_1105_1.met
# Weather and Soil Variables extracted for field 1105-1
# Transforming shp to WGS 84
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
# Note: Kf and Kw have numeric values at the chorizon level,
# they are really categorical data and only available to the minmax aggegation method
#    SAND  CLAY  SILT    BD  ...   CEC   THICK  id_cell  id_within_cell
# 0  18.0  32.0  50.0  1.64  ...  18.0   180.0     1073               3
# 1  22.0  41.0  37.0  1.75  ...  21.5   460.0     1073               3
# 2  24.0  36.0  40.0  1.78  ...  20.0   100.0     1073               3
# 3  22.0  32.0  46.0  1.80  ...  11.6  1260.0     1073               3
#
# [4 rows x 30 columns]
# .met file created succesfully: /workspace/weather/w_id_1073_3.met
# Weather and Soil Variables extracted for field 1073-3
# Variables extracted successful!!! step 3/4

# %%
# !python -m _4preproccesing
# Out:
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# 2006-01-01T00:00:00
# 2023-12-31T00:00:00
# Preproccesing completed!!! Step 4/4 Now you can run simulations in APSIM

# %%
# !python -m _5RunSimulations
# Out:
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# Simulation successful!
# Simulation successful!
# Simulation successful!
# Simulation successful!
# Simulations Finished for : 605 2
# 2006-01-01T00:00:00
# 2022-12-31T00:00:00
# Simulation successful!
# ^C
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/subprocess.py", line 1209, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/subprocess.py", line 2115, in _communicate
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/workspace/workflow/_5RunSimulations/__main__.py", line 31, in <module>
#     sim1.run()
#   File "/workspace/apsimxpy/__init__.py", line 40, in run
#     result = subprocess.run(self.command, check=True, capture_output=True, text=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/subprocess.py", line 1220, in communicate
#     self._wait(timeout=sigint_timeout)
#   File "/usr/local/lib/python3.12/subprocess.py", line 2047, in _wait
#     time.sleep(delay)
# KeyboardInterrupt
